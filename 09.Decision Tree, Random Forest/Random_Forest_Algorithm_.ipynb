# %% [markdown]
# <a href="https://colab.research.google.com/github/Prasadkpd/Machine-Learning/blob/master/Decision%20Tree%2C%20Random%20Forest/Random_Forest_Algorithm_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Random Forest is a Tree-based, supervised machine learning algorithm that can be used for both classification and regression problems. But mostly used for classification problems. It consists of a number of Decision Trees.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Implementation

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('kyphosis.csv')
data.head()
# Out:
#   Kyphosis  Age  Number  Start
# 0   absent   71       3      5
# 1   absent  158       3     14
# 2  present  128       4      5
# 3   absent    2       5      1
# 4   absent    1       4     15

# %%
data.shape
# Out:
# (81, 4)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Kyphosis  81 non-null     object
#  1   Age       81 non-null     int64
#  2   Number    81 non-null     int64
#  3   Start     81 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 2.7+ KB

# %%
x = data.drop('Kyphosis', axis=1)
x.head()
# Out:
#    Age  Number  Start
# 0   71       3      5
# 1  158       3     14
# 2  128       4      5
# 3    2       5      1
# 4    1       4     15

# %%
y = data['Kyphosis']
y.head()
# Out:
# 0     absent
# 1     absent
# 2    present
# 3     absent
# 4     absent
# Name: Kyphosis, dtype: object

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3)

# %%
x_train.shape
# Out:
# (56, 3)

# %%
x_test.shape
# Out:
# (25, 3)

# %% [markdown]
# # Random Forest Algo

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators= 50)
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=50)

# %%
pred = model.predict(x_test)
pred
# Out:
# array(['absent', 'absent', 'absent', 'absent', 'absent', 'absent',
#        'absent', 'absent', 'absent', 'absent', 'absent', 'absent',
#        'absent', 'present', 'absent', 'absent', 'absent', 'absent',
#        'absent', 'present', 'absent', 'absent', 'absent', 'absent',
#        'absent'], dtype=object)

# %%
y_test
# Out:
# 14     absent
# 62     absent
# 41     absent
# 59     absent
# 26     absent
# 76    present
# 31     absent
# 47     absent
# 40    present
# 7      absent
# 3      absent
# 33     absent
# 69     absent
# 2     present
# 39    present
# 56     absent
# 65     absent
# 71     absent
# 22    present
# 23     absent
# 45    present
# 37    present
# 0      absent
# 57    present
# 73     absent
# Name: Kyphosis, dtype: object

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,pred)
# Out:
# 0.68

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, pred)
# Out:
# array([[16,  1],
#        [ 7,  1]])
