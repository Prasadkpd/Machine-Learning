# %% [markdown]
# <a href="https://colab.research.google.com/github/Prasadkpd/Machine-Learning/blob/master/Decision%20Tree%2C%20Random%20Forest/Decision_Tree_Algorithm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # How select what featuer have to cpnsider first
# There are four techniques to get that
#
#
# 1.   Entropy
# 2.   Information Gain
# 3.   Gini Index
# 4.   Chi-Square

# %% [markdown]
# # How Calculate Entropy
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## The lowest entropy dicision tree get as the decision tree

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("kyphosis.csv")
data.head
# Out:
#   Kyphosis  Age  Number  Start
# 0   absent   71       3      5
# 1   absent  158       3     14
# 2  present  128       4      5
# 3   absent    2       5      1
# 4   absent    1       4     15

# %%
data.shape
# Out:
# (81, 4)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Kyphosis  81 non-null     object
#  1   Age       81 non-null     int64
#  2   Number    81 non-null     int64
#  3   Start     81 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 2.7+ KB

# %%
# Remove kyphosis column
x = data.drop('Kyphosis',axis=1)
x.head()
# Out:
#    Age  Number  Start
# 0   71       3      5
# 1  158       3     14
# 2  128       4      5
# 3    2       5      1
# 4    1       4     15

# %%
y = data['Kyphosis']
y.head()
# Out:
# 0     absent
# 1     absent
# 2    present
# 3     absent
# 4     absent
# Name: Kyphosis, dtype: object

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3)

# %%
x_train.shape
# Out:
# (56, 3)

# %%
x_test.shape
# Out:
# (25, 3)

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred = model.predict(x_test)

# %%
y_test
# Out:
# 52    present
# 37    present
# 18     absent
# 47     absent
# 10    present
# 24    present
# 50     absent
# 0      absent
# 31     absent
# 1      absent
# 53     absent
# 75     absent
# 51     absent
# 19     absent
# 34     absent
# 14     absent
# 25     absent
# 71     absent
# 7      absent
# 59     absent
# 48    present
# 63     absent
# 17     absent
# 38     absent
# 8      absent
# Name: Kyphosis, dtype: object

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, pred)
# Out:
# 0.72

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, pred)
# Out:
# array([[15,  5],
#        [ 2,  3]])

# %% [markdown]
# #### Adv - This is simple and easy to use algorithm and train model quickly
# #### Dis - This can be happen overfitting
