# %% [markdown]
# <a href="https://colab.research.google.com/github/Prasadkpd/Machine-Learning/blob/master/Naive_Bayes_Algorithm/Naive_Bayes_Algorithm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Naive Bayes Algorithm

# %% [markdown]
# Naive Bayes is a supervised machine learning algorithm, which is used for classification problems. Naive Bayes algorithm based on Bayes theorem. It is a simple algorithm. But also fast, accurate, and most effective classification algorithm.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * Gaussian: It is used in classification and it assumes that features follow a normal distribution.
#
# * Multinomial: It is used for discrete counts. For example, let’s say,  we have a text classification problem. Here we can consider Bernoulli trials which is one step further and instead of “word occurring in the document”, we have “count how often word occurs in the document”, you can think of it as “number of times outcome number x_i is observed over the n trials”.
#
# * Bernoulli: The binomial model is useful if your feature vectors are binary (i.e. zeros and ones). One application would be text classification with ‘bag of words’ model where the 1s & 0s are “word occurs in the document” and “word does not occur in the document” respectively.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Implementation of Naive Bayes

# %% [markdown]
# ## Load Dataset

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('kyphosis.csv')

# %%
data.head()
# Out:
#   Kyphosis  Age  Number  Start
# 0   absent   71       3      5
# 1   absent  158       3     14
# 2  present  128       4      5
# 3   absent    2       5      1
# 4   absent    1       4     15

# %%
data.shape
# Out:
# (81, 4)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Kyphosis  81 non-null     object
#  1   Age       81 non-null     int64
#  2   Number    81 non-null     int64
#  3   Start     81 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 2.7+ KB

# %%
# Visualize the data
import seaborn as sns
sns.pairplot(data,hue="Kyphosis")

# %%
# Visualize the counterplot
sns.countplot(x='Kyphosis', data=data)

# %% [markdown]
# ## Data Pre-Process

# %%
x = data.drop('Kyphosis', axis=1)

# %%
x.head()
# Out:
#    Age  Number  Start
# 0   71       3      5
# 1  158       3     14
# 2  128       4      5
# 3    2       5      1
# 4    1       4     15

# %%
y = data['Kyphosis']
y.head()
# Out:
# 0     absent
# 1     absent
# 2    present
# 3     absent
# 4     absent
# Name: Kyphosis, dtype: object

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)

# %%
x_train.shape
# Out:
# (56, 3)

# %%
x_train.shape
# Out:
# (56, 3)

# %% [markdown]
# ## Gaussian Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
pred = model.predict(x_test)
pred
# Out:
# array(['absent', 'present', 'absent', 'present', 'absent', 'absent',
#        'absent', 'absent', 'absent', 'absent', 'present', 'absent',
#        'absent', 'absent', 'present', 'absent', 'absent', 'absent',
#        'absent', 'absent', 'absent', 'absent', 'absent', 'absent',
#        'absent'], dtype='<U7')

# %%
y_test
# Out:
# 55     absent
# 21    present
# 56     absent
# 12     absent
# 68     absent
# 77     absent
# 53     absent
# 39    present
# 15     absent
# 10    present
# 61    present
# 16     absent
# 69     absent
# 45    present
# 58     absent
# 49     absent
# 51     absent
# 74     absent
# 34     absent
# 59     absent
# 26     absent
# 41     absent
# 75     absent
# 27     absent
# 72     absent
# Name: Kyphosis, dtype: object

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, pred)
# Out:
# 0.8

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, pred)
# Out:
# array([[18,  2],
#        [ 3,  2]])
