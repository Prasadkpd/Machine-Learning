# %% [markdown]
# <a href="https://colab.research.google.com/github/Prasadkpd/Machine-Learning/blob/master/Support%20Vector%20Machine/Support_Vector_Machine_(SVM).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Support Vector Machine (SVM)

# %% [markdown]
# * Support vector machine also known as SVM is a supervised machine learning algorithm that can be used for both regression and classification problems. However, SVM is mostly used for classification problems in the machine learning world.
# * The goal of SVM is to find a hyperplane in N-dimensional space. The hyperplane is a boundary that classifies data points into classes.

# %% [markdown]
# ## Hyperplane
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## How Find Best Hyperplane

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## In Some Cases
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Implementation of Support Vector Machine

# %% [markdown]
# ## Load DataSet

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('Iris.csv')
data.sample(5)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 102  103            7.1           3.0            5.9           2.1
# 129  130            7.2           3.0            5.8           1.6
# 49    50            5.0           3.3            1.4           0.2
# 42    43            4.4           3.2            1.3           0.2
# 116  117            6.5           3.0            5.5           1.8
#
#             Species
# 102  Iris-virginica
# 129  Iris-virginica
# 49      Iris-setosa
# 42      Iris-setosa
# 116  Iris-virginica

# %%
data.shape
# Out:
# (150, 6)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
# Visualize the data
import seaborn as sns
sns.pairplot(data,hue="Species")

# %%
#  Visualize the counterplot
sns.countplot(x='Species', data=data)

# %% [markdown]
# ## Data Pre-Process

# %%
data = data.drop('Id', axis=1)

# %%
data.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
x = data.drop('Species', axis=1)
x.sample(5)
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 52             6.9           3.1            4.9           1.5
# 82             5.8           2.7            3.9           1.2
# 105            7.6           3.0            6.6           2.1
# 44             5.1           3.8            1.9           0.4
# 64             5.6           2.9            3.6           1.3

# %%
y = data['Species']
y.sample(5)
# Out:
# 121     Iris-virginica
# 9          Iris-setosa
# 37         Iris-setosa
# 59     Iris-versicolor
# 131     Iris-virginica
# Name: Species, dtype: object

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
x_train.shape
# Out:
# (120, 4)

# %%
x_test.shape
# Out:
# (30, 4)

# %%
from sklearn.svm import SVC
model = SVC(kernel='poly', C=10)
model.fit(x_train, y_train)
# Out:
# SVC(C=10, kernel='poly')

# %%
model.kernel
# Out:
# 'poly'

# %%
pred = model.predict(x_test)

# %%
pred
# Out:
# array(['Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-setosa', 'Iris-virginica', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-virginica', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa'], dtype=object)

# %%
y_test
# Out:
# 123     Iris-virginica
# 100     Iris-virginica
# 131     Iris-virginica
# 33         Iris-setosa
# 70     Iris-versicolor
# 147     Iris-virginica
# 52     Iris-versicolor
# 77     Iris-versicolor
# 38         Iris-setosa
# 20         Iris-setosa
# 3          Iris-setosa
# 12         Iris-setosa
# 43         Iris-setosa
# 96     Iris-versicolor
# 72     Iris-versicolor
# 71     Iris-versicolor
# 15         Iris-setosa
# 139     Iris-virginica
# 21         Iris-setosa
# 82     Iris-versicolor
# 22         Iris-setosa
# 36         Iris-setosa
# 40         Iris-setosa
# 119     Iris-virginica
# 46         Iris-setosa
# 84     Iris-versicolor
# 81     Iris-versicolor
# 140     Iris-virginica
# 93     Iris-versicolor
# 18         Iris-setosa
# Name: Species, dtype: object

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, pred)
# Out:
# 0.9

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, pred)
# Out:
# array([[13,  0,  0],
#        [ 0,  7,  3],
#        [ 0,  0,  7]])
