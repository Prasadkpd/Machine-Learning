# %% [markdown]
# <a href="https://colab.research.google.com/github/Prasadkpd/Machine-Learning/blob/master/Distance%20Metrices/Distance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## In Python

# %%
A = (5, 3)
B = (2, 4)

# %%
from scipy.spatial import distance

# %%
# Euclidean Distance

d = distance.euclidean(A, B)
print(d)
# Out:
# 3.1622776601683795

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## In Python

# %%
A = (5, 3)
B = (2, 4)

# %%
from scipy.spatial import distance

# %%
# Manhatton Distance

d = distance.cityblock(A, B)
print(d)
# Out:
# 4

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## In Python

# %%
A = (5, 3)
B = (2, 4)

# %%
from scipy.spatial import distance

# %%
# Cosine Distance

d = distance.cosine(A, B)
print(d)
# Out:
# 0.15633851226789253
